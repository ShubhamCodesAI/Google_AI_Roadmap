# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamCodesAI/Google_AI_Roadmap/blob/main/MAY_03_CALCULATOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = input("Enter first number")
num2 = input("Enter second number")

result= float(num1) + float(num2)

print(f"The total of {num1} and {num2}is: {result}")
# Out:
# Enter first number18.5
# Enter second number2.5
# The total of 18.5 and 2.5is: 21.0

# %%
num1 = input("Enter First Number:")
num2 = input("Enter Second Number:")

result = float(num1)+float(num2)

print(f"Your total of {num1} and {num2} is: {result}")
# Out:
# Enter First Number:67
# Enter Second Number:76
# Your total of 67 and 76 is: 143.0

# %%
num1 = float(input("Enter First Number:"))
num2 = float(input("Enter Second Number:"))

sum_res = num1 + num2
diff_res = num1- num2
mult_res = num1*num2
div_res = num1/num2

print("-"*30)
print(f"Result for {num1} and {num2}:")
print(f"addition:         {sum_res}")
print(f"subtraction:      {diff_res}")
print(f"multiplication:   {mult_res}")
print(f"division:         {div_res}")
print("-"*30)
# Out:
# Enter First Number:69
# Enter Second Number:56
# ------------------------------
# Result for 69.0 and 56.0:
# addition:         125.0
# subtraction:      13.0
# multiplication:   3864.0
# division:         1.2321428571428572
# ------------------------------
