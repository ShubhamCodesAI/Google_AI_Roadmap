# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamCodesAI/Google_AI_Roadmap/blob/main/MAY_02_MASTERY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Objective: Mastering Variables & Data Types

# %%
my_name = "Shubham"
current_class = 11
target_salary_lpa = 120.5
on_google_track = True

print(f"My name is {my_name}. I am in {current_class}. Standard")
print(f"Goal: Google AI Engineer earning {target_salary_lpa} LPA.")
print(f"Commitment to the grind {on_google_track}.")
# Out:
# My name is Shubham. I am in 11. Standard
# Goal: Google AI Engineer earning 120.5 LPA.
# Commitment to the grind True.

# %%
phrase = "Sundar Pichai"
print(phrase[7])
# Out:
# P

# %%
phrase = "Shubham Rawat"
print(phrase.index("R"))
# Out:
# 8

# %%
phrase = "Jullian Shakespeare"
print(phrase.replace("Jullian", "William"))
# Out:
# William Shakespeare

# %%
name = "Sundar Pichai"
big_name = name.upper()
print(big_name.isupper())
# Out:
# True

# %%
print(2-1)
print(9+8)
print(5*78)
print(9/3)
print( 2+(9*10))
print(10%3)
# Out:
# 1
# 17
# 390
# 3.0
# 92
# 1

# %%
my_num = 22
print(str(my_num))
print(str(my_num) + " is my favourite number because it is the date when i was born in aug.")
# Out:
# 22
# 22 is my favourite number because it is the date when i was born in aug.

# %%
from math import*
my_num = -90
print(abs(my_num))
print(pow(9,3))
print(max(2,9))
print(min(6,-2))
print(round(69.8569))
print(round(69.2134))
print(floor(99.6))
print(ceil(99.6))
print(sqrt(16))
# Out:
# 90
# 729.0
# 9
# -2
# 70
# 69
# 99
# 100
# 6.0
